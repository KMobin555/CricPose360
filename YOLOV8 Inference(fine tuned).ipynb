# %%
# !pip install ultralytics opencv-python scikit-image
# !pip install -U ipywidgets
# Out:
# Requirement already satisfied: ultralytics in /opt/conda/lib/python3.10/site-packages (8.2.82)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.0.5)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# !cp -r /kaggle/input/trainable-yolo-cls/* /kaggle/working/

# %%
# !rm -r /kaggle/working/processed_data/test

# %%
data_yaml_content = """
train: /kaggle/working/processed_data/train
val: /kaggle/working/processed_data/val

nc: 10  # Number of classes
names: ['sweep', 'square_cut', 'hook', 'lofted', 'cover', 'late_cut', 'pull', 'defense', 'flick', 'straight']
"""


# Path where you want to save the data.yaml file
yaml_file_path = '/kaggle/working/data.yaml'

# Save the YAML content to the file
with open(yaml_file_path, 'w') as file:
    file.write(data_yaml_content)

# Confirm the file has been saved
print(f"data.yaml saved at: {yaml_file_path}")

# %%
# Read the YAML file content (optional)
with open(yaml_file_path, 'r') as file:
    content = file.read()
    print(content)

# %%
# Initialize Weights & Biases (W&B) in disabled mode.

import wandb
wandb.init(mode="disabled")

# %%
import pandas as pd
import os

# Base directory for the test videos
test_base_dir = '/kaggle/working/cricshot-split/test'  # Update this path to where your test videos are stored

# Prepare the ground truth DataFrame by scanning the test directory
ground_truth_data = []
for class_name in os.listdir(test_base_dir):
    class_dir = os.path.join(test_base_dir, class_name)
    if os.path.isdir(class_dir):
        for video_name in os.listdir(class_dir):
            if video_name.endswith('.mp4'):  # Assuming the videos are in .mp4 format
                ground_truth_data.append({
                    'video_name': video_name,
                    'true_class': class_name
                })

# Convert to a DataFrame
ground_truth_df = pd.DataFrame(ground_truth_data)
print(ground_truth_df)
# Out:
#            video_name true_class
# 0      cover_0112.mp4      cover
# 1      cover_0043.mp4      cover
# 2      cover_0131.mp4      cover
# 3      cover_0061.mp4      cover
# 4      cover_0160.mp4      cover
# ..                ...        ...
# 190  defense_0118.mp4    defense
# 191  defense_0004.mp4    defense
# 192  defense_0141.mp4    defense
# 193  defense_0164.mp4    defense
# 194  defense_0011.mp4    defense
#
# [195 rows x 2 columns]

# %%
import cv2
import os
import pandas as pd
from ultralytics import YOLO
from collections import Counter, defaultdict

saved_model_path = '/kaggle/input/yolov8-l-cls-23-eps-v2/pytorch/default/1/best(1).pt'
# saved_model_path = '/kaggle/working/runs/classify/train/weights/best.pt'

# Load the trained YOLOv8 model
model = YOLO(saved_model_path)  # Update to your trained model path

# Initialize a list to store predictions
predictions = []

# Function to extract exactly 32 frames from a video
def extract_frames(video_path, num_frames=32, img_size=(640, 640)):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if frame_count < num_frames:
        raise ValueError(f"Video {video_path} has fewer frames ({frame_count}) than requested ({num_frames}).")
    
    interval = max(1, frame_count // num_frames)
    frames = []
    for i in range(num_frames):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * interval)
        ret, frame = cap.read()
        if not ret:
            break
        resized_frame = cv2.resize(frame, img_size)
        frames.append(resized_frame)
    cap.release()
    return frames

# Loop through the test directories and videos
for class_name in os.listdir(test_base_dir):
    class_dir = os.path.join(test_base_dir, class_name)
    if os.path.isdir(class_dir):
        for video_name in os.listdir(class_dir):
            if video_name.endswith('.mp4'):
                video_path = os.path.join(class_dir, video_name)
                
                try:
                    # Extract 32 frames from the video
                    frames = extract_frames(video_path, num_frames=32)
                    
                    # Predict on video frames
                    results = model.predict(frames)
#                     print(results[0].probs.top1)
                    # Initialize a dictionary to accumulate class probabilities
                    class_probabilities = defaultdict(list)

                    # Collect frame-level probabilities
                    for result in results:
                        top_class = result.names[result.probs.top1]
                        top_prob = result.probs.top1conf.item()
                        class_probabilities[top_class].append(top_prob)
                    
                    # Calculate average probability for each class
                    avg_class_probabilities = {cls: sum(probs) / len(results) for cls, probs in class_probabilities.items()}
                    
                    print(avg_class_probabilities)
                    
                    # Determine the class with the highest average probability
                    most_probable_class = max(avg_class_probabilities, key=avg_class_probabilities.get)
                    
                    print(f"Video: {video_name}, Most Probable Class: {most_probable_class}, Avg Probability: {avg_class_probabilities[most_probable_class]:.4f}")
                    
                    # Store the prediction
                    predictions.append({
                        'video_name': video_name,
                        'true_class': class_name,
                        'predicted_class': most_probable_class,
                        'avg_probability': avg_class_probabilities[most_probable_class]
                    })
                except ValueError as e:
                    print(f"Skipping {video_path}: {e}")
                    
                    
# Convert predictions to a DataFrame
predictions_df = pd.DataFrame(predictions)
print(predictions_df)

# Example: Print the predicted class for the first video
if not predictions_df.empty:
    first_prediction = predictions_df.iloc[0]
    print(f"Video: {first_prediction['video_name']}, Predicted Class: {first_prediction['predicted_class']}")
# Out:
# 0: 640x640 pull 0.58, square_cut 0.14, hook 0.12, late_cut 0.06, flick 0.03, 10.8ms
# 1: 640x640 pull 0.58, hook 0.18, square_cut 0.12, flick 0.04, late_cut 0.04, 10.8ms
# 2: 640x640 square_cut 0.32, hook 0.26, pull 0.25, flick 0.07, cover 0.05, 10.8ms
# 3: 640x640 square_cut 0.56, pull 0.31, hook 0.07, cover 0.01, sweep 0.01, 10.8ms
# 4: 640x640 pull 0.51, square_cut 0.27, hook 0.10, late_cut 0.05, cover 0.02, 10.8ms
# 5: 640x640 pull 0.53, square_cut 0.14, hook 0.14, late_cut 0.10, lofted 0.05, 10.8ms
# 6: 640x640 pull 0.57, hook 0.17, late_cut 0.09, lofted 0.05, square_cut 0.04, 10.8ms
# 7: 640x640 pull 0.52, hook 0.18, square_cut 0.10, late_cut 0.08, flick 0.05, 10.8ms
# 8: 640x640 pull 0.64, hook 0.24, square_cut 0.07, lofted 0.02, flick 0.01, 10.8ms
# 9: 640x640 pull 0.59, hook 0.18, square_cut 0.12, flick 0.05, cover 0.03, 10.8ms
# 10: 640x640 square_cut 0.44, pull 0.38, flick 0.11, hook 0.05, lofted 0.01, 10.8ms
# 11: 640x640 pull 0.69, square_cut 0.09, hook 0.08, flick 0.06, lofted 0.04, 10.8ms
# 12: 640x640 pull 0.74, hook 0.12, sweep 0.05, square_cut 0.03, flick 0.03, 10.8ms
# 13: 640x640 pull 0.93, hook 0.07, square_cut 0.00, sweep 0.00, flick 0.00, 10.8ms
# 14: 640x640 pull 0.98, square_cut 0.01, hook 0.01, sweep 0.00, lofted 0.00, 10.8ms
# 15: 640x640 pull 0.52, square_cut 0.47, hook 0.01, flick 0.00, lofted 0.00, 10.8ms
# 16: 640x640 square_cut 0.55, pull 0.43, lofted 0.01, cover 0.01, flick 0.01, 10.8ms
# 17: 640x640 pull 0.59, square_cut 0.20, cover 0.12, lofted 0.09, flick 0.00, 10.8ms
# 18: 640x640 square_cut 0.81, pull 0.11, cover 0.05, lofted 0.02, late_cut 0.00, 10.8ms
# 19: 640x640 square_cut 0.77, lofted 0.08, cover 0.07, pull 0.05, late_cut 0.02, 10.8ms
# 20: 640x640 square_cut 0.80, cover 0.13, lofted 0.05, pull 0.01, straight 0.01, 10.8ms
# 21: 640x640 square_cut 0.72, cover 0.10, lofted 0.08, late_cut 0.06, pull 0.04, 10.8ms
# 22: 640x640 late_cut 0.40, square_cut 0.25, cover 0.22, pull 0.09, lofted 0.04, 10.8ms
# 23: 640x640 square_cut 0.38, pull 0.32, cover 0.15, late_cut 0.09, lofted 0.04, 10.8ms
# 24: 640x640 pull 0.38, square_cut 0.33, cover 0.16, late_cut 0.06, lofted 0.03, 10.8ms
# 25: 640x640 cover 0.44, pull 0.37, square_cut 0.09, lofted 0.04, sweep 0.02, 10.8ms
# 26: 640x640 pull 0.51, cover 0.26, square_cut 0.15, sweep 0.03, lofted 0.02, 10.8ms
# 27: 640x640 sweep 0.41, square_cut 0.22, cover 0.21, pull 0.10, lofted 0.02, 10.8ms
# 28: 640x640 square_cut 0.60, sweep 0.18, cover 0.13, pull 0.07, lofted 0.01, 10.8ms
# 29: 640x640 sweep 0.35, square_cut 0.34, pull 0.17, cover 0.11, straight 0.02, 10.8ms
# 30: 640x640 pull 0.68, square_cut 0.17, lofted 0.10, cover 0.03, hook 0.01, 10.8ms
# 31: 640x640 square_cut 0.64, pull 0.32, lofted 0.03, flick 0.01, cover 0.00, 10.8ms
# Speed: 14.7ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'pull': 0.32964183297008276, 'square_cut': 0.20580896828323603, 'late_cut': 0.012455107644200325, 'cover': 0.013627088628709316, 'sweep': 0.023718005046248436}
# Video: cover_0112.mp4, Most Probable Class: pull, Avg Probability: 0.3296
#
# 0: 640x640 flick 0.49, hook 0.33, pull 0.07, lofted 0.05, square_cut 0.04, 10.3ms
# 1: 640x640 flick 0.59, hook 0.26, pull 0.08, lofted 0.02, square_cut 0.02, 10.3ms
# 2: 640x640 flick 0.77, hook 0.12, cover 0.04, pull 0.03, square_cut 0.01, 10.3ms
# 3: 640x640 flick 0.84, hook 0.07, cover 0.03, square_cut 0.03, pull 0.01, 10.3ms
# 4: 640x640 flick 0.47, hook 0.37, cover 0.06, pull 0.03, square_cut 0.03, 10.3ms
# 5: 640x640 flick 0.58, hook 0.22, cover 0.08, pull 0.04, late_cut 0.03, 10.3ms
# 6: 640x640 hook 0.37, flick 0.35, late_cut 0.08, square_cut 0.07, pull 0.06, 10.3ms
# 7: 640x640 flick 0.36, hook 0.25, pull 0.19, square_cut 0.12, late_cut 0.03, 10.3ms
# 8: 640x640 flick 0.53, hook 0.25, square_cut 0.09, pull 0.08, lofted 0.02, 10.3ms
# 9: 640x640 hook 0.33, flick 0.26, square_cut 0.17, pull 0.11, late_cut 0.10, 10.3ms
# 10: 640x640 flick 0.69, hook 0.10, pull 0.06, late_cut 0.05, square_cut 0.05, 10.3ms
# 11: 640x640 flick 0.33, hook 0.32, late_cut 0.12, lofted 0.06, pull 0.06, 10.3ms
# 12: 640x640 flick 0.28, pull 0.20, sweep 0.17, square_cut 0.13, late_cut 0.08, 10.3ms
# 13: 640x640 square_cut 0.63, flick 0.16, lofted 0.09, pull 0.06, cover 0.03, 10.3ms
# 14: 640x640 square_cut 0.87, flick 0.03, sweep 0.03, straight 0.02, late_cut 0.01, 10.3ms
# 15: 640x640 square_cut 0.56, straight 0.25, cover 0.09, lofted 0.05, flick 0.04, 10.3ms
# 16: 640x640 straight 0.78, square_cut 0.08, cover 0.05, flick 0.05, lofted 0.02, 10.3ms
# 17: 640x640 cover 0.36, straight 0.16, square_cut 0.15, late_cut 0.13, lofted 0.08, 10.3ms
# 18: 640x640 cover 0.30, late_cut 0.23, square_cut 0.14, flick 0.12, lofted 0.09, 10.3ms
# 19: 640x640 square_cut 0.24, flick 0.24, pull 0.20, lofted 0.12, cover 0.12, 10.3ms
# 20: 640x640 flick 0.63, pull 0.23, square_cut 0.10, sweep 0.01, straight 0.01, 10.3ms
# 21: 640x640 square_cut 0.34, flick 0.26, cover 0.24, straight 0.05, sweep 0.05, 10.3ms
# 22: 640x640 cover 0.42, square_cut 0.23, flick 0.16, sweep 0.13, straight 0.03, 10.3ms
# 23: 640x640 cover 0.75, square_cut 0.08, flick 0.07, pull 0.04, lofted 0.03, 10.3ms
# 24: 640x640 cover 0.86, flick 0.06, straight 0.03, square_cut 0.02, pull 0.02, 10.3ms
# 25: 640x640 cover 0.88, flick 0.05, square_cut 0.03, lofted 0.02, straight 0.02, 10.3ms
# 26: 640x640 cover 0.77, flick 0.10, lofted 0.05, square_cut 0.04, straight 0.03, 10.3ms
# 27: 640x640 lofted 0.42, cover 0.27, square_cut 0.13, straight 0.08, flick 0.08, 10.3ms
# 28: 640x640 cover 0.48, lofted 0.27, square_cut 0.17, straight 0.05, flick 0.02, 10.3ms
# 29: 640x640 cover 0.68, lofted 0.13, square_cut 0.10, straight 0.06, flick 0.03, 10.3ms
# 30: 640x640 straight 0.40, cover 0.37, lofted 0.18, square_cut 0.03, sweep 0.00, 10.3ms
# 31: 640x640 cover 0.50, lofted 0.32, straight 0.15, square_cut 0.02, flick 0.01, 10.3ms
# Speed: 11.9ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'flick': 0.20554582122713327, 'hook': 0.02173290215432644, 'square_cut': 0.08245739666745067, 'straight': 0.036935579031705856, 'cover': 0.18684232607483864, 'lofted': 0.013164547272026539}
# Video: cover_0043.mp4, Most Probable Class: flick, Avg Probability: 0.2055
#
# 0: 640x640 cover 0.37, flick 0.34, lofted 0.22, square_cut 0.05, pull 0.02, 10.3ms
# 1: 640x640 flick 0.42, cover 0.29, lofted 0.23, square_cut 0.04, pull 0.01, 10.3ms
# 2: 640x640 flick 0.37, lofted 0.30, cover 0.23, square_cut 0.05, pull 0.03, 10.3ms
# 3: 640x640 lofted 0.34, cover 0.33, flick 0.27, square_cut 0.05, pull 0.01, 10.3ms
# 4: 640x640 cover 0.48, lofted 0.25, flick 0.21, square_cut 0.06, pull 0.01, 10.3ms
# 5: 640x640 cover 0.67, lofted 0.13, flick 0.12, square_cut 0.05, pull 0.02, 10.3ms
# 6: 640x640 cover 0.71, lofted 0.13, flick 0.13, square_cut 0.02, pull 0.01, 10.3ms
# 7: 640x640 cover 0.81, lofted 0.14, flick 0.03, square_cut 0.01, pull 0.01, 10.3ms
# 8: 640x640 cover 0.87, lofted 0.10, flick 0.02, square_cut 0.01, pull 0.00, 10.3ms
# 9: 640x640 cover 0.81, lofted 0.14, flick 0.04, square_cut 0.01, pull 0.00, 10.3ms
# 10: 640x640 cover 0.73, lofted 0.22, square_cut 0.02, flick 0.02, pull 0.01, 10.3ms
# 11: 640x640 cover 0.76, lofted 0.20, flick 0.02, square_cut 0.01, pull 0.00, 10.3ms
# 12: 640x640 cover 0.87, lofted 0.09, flick 0.02, square_cut 0.02, pull 0.00, 10.3ms
# 13: 640x640 cover 0.67, lofted 0.17, flick 0.12, square_cut 0.03, pull 0.01, 10.3ms
# 14: 640x640 cover 0.58, lofted 0.28, flick 0.07, square_cut 0.05, pull 0.02, 10.3ms
# 15: 640x640 cover 0.61, lofted 0.18, flick 0.10, square_cut 0.08, pull 0.02, 10.3ms
# 16: 640x640 cover 0.40, lofted 0.27, flick 0.16, square_cut 0.14, pull 0.03, 10.3ms
# 17: 640x640 lofted 0.52, cover 0.38, square_cut 0.05, flick 0.03, pull 0.01, 10.3ms
# 18: 640x640 cover 0.52, flick 0.18, lofted 0.17, square_cut 0.12, pull 0.00, 10.3ms
# 19: 640x640 cover 0.50, square_cut 0.23, flick 0.13, lofted 0.13, pull 0.00, 10.3ms
# 20: 640x640 cover 0.51, flick 0.17, square_cut 0.16, lofted 0.15, pull 0.00, 10.3ms
# 21: 640x640 square_cut 0.51, cover 0.22, flick 0.18, lofted 0.09, pull 0.00, 10.3ms
# 22: 640x640 lofted 0.62, cover 0.27, flick 0.06, square_cut 0.03, pull 0.01, 10.3ms
# 23: 640x640 lofted 0.61, cover 0.27, square_cut 0.06, flick 0.03, pull 0.01, 10.3ms
# 24: 640x640 lofted 0.49, cover 0.22, square_cut 0.10, flick 0.08, sweep 0.07, 10.3ms
# 25: 640x640 lofted 0.67, cover 0.13, square_cut 0.13, sweep 0.03, flick 0.02, 10.3ms
# 26: 640x640 lofted 0.49, square_cut 0.18, cover 0.15, flick 0.10, pull 0.08, 10.3ms
# 27: 640x640 lofted 0.76, square_cut 0.11, flick 0.07, cover 0.04, pull 0.02, 10.3ms
# 28: 640x640 lofted 0.65, cover 0.13, square_cut 0.12, flick 0.07, sweep 0.02, 10.3ms
# 29: 640x640 lofted 0.48, cover 0.25, flick 0.16, square_cut 0.07, sweep 0.03, 10.3ms
# 30: 640x640 lofted 0.43, cover 0.31, flick 0.22, straight 0.02, square_cut 0.01, 10.3ms
# 31: 640x640 flick 0.36, lofted 0.24, sweep 0.19, cover 0.12, square_cut 0.08, 10.3ms
# Speed: 11.7ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'cover': 0.33995516411960125, 'flick': 0.03591504134237766, 'lofted': 0.189814162440598, 'square_cut': 0.01579468324780464}
# Video: cover_0131.mp4, Most Probable Class: cover, Avg Probability: 0.3400
#
# 0: 640x640 lofted 0.58, pull 0.14, straight 0.13, square_cut 0.06, hook 0.03, 10.3ms
# 1: 640x640 lofted 0.60, pull 0.15, straight 0.12, square_cut 0.06, hook 0.02, 10.3ms
# 2: 640x640 straight 0.45, lofted 0.23, pull 0.12, square_cut 0.11, flick 0.04, 10.3ms
# 3: 640x640 straight 0.47, pull 0.19, lofted 0.13, square_cut 0.12, late_cut 0.03, 10.3ms
# 4: 640x640 straight 0.55, pull 0.28, square_cut 0.06, lofted 0.06, hook 0.03, 10.3ms
# 5: 640x640 straight 0.46, pull 0.39, square_cut 0.08, lofted 0.03, flick 0.01, 10.3ms
# 6: 640x640 straight 0.58, pull 0.34, square_cut 0.04, lofted 0.02, hook 0.01, 10.3ms
# 7: 640x640 straight 0.86, pull 0.09, lofted 0.03, square_cut 0.01, flick 0.01, 10.3ms
# 8: 640x640 straight 0.73, lofted 0.10, pull 0.09, square_cut 0.03, late_cut 0.03, 10.3ms
# 9: 640x640 straight 0.40, late_cut 0.39, pull 0.09, lofted 0.05, flick 0.04, 10.3ms
# 10: 640x640 straight 0.51, late_cut 0.31, pull 0.08, square_cut 0.05, lofted 0.02, 10.3ms
# 11: 640x640 straight 0.66, late_cut 0.19, pull 0.06, lofted 0.03, flick 0.03, 10.3ms
# 12: 640x640 pull 0.30, straight 0.22, lofted 0.20, square_cut 0.13, late_cut 0.10, 10.3ms
# 13: 640x640 pull 0.62, straight 0.22, lofted 0.05, late_cut 0.04, square_cut 0.04, 10.3ms
# 14: 640x640 pull 0.73, straight 0.10, late_cut 0.07, lofted 0.05, square_cut 0.03, 10.3ms
# 15: 640x640 pull 0.38, square_cut 0.20, late_cut 0.17, lofted 0.15, straight 0.07, 10.3ms
# 16: 640x640 pull 0.43, late_cut 0.24, square_cut 0.22, straight 0.06, lofted 0.02, 10.3ms
# 17: 640x640 late_cut 0.39, pull 0.39, lofted 0.09, straight 0.06, square_cut 0.05, 10.3ms
# 18: 640x640 pull 0.71, late_cut 0.19, straight 0.03, lofted 0.03, square_cut 0.03, 10.3ms
# 19: 640x640 pull 0.79, late_cut 0.13, square_cut 0.03, lofted 0.03, straight 0.02, 10.3ms
# 20: 640x640 pull 0.64, straight 0.12, lofted 0.11, square_cut 0.06, late_cut 0.06, 10.3ms
# 21: 640x640 late_cut 0.35, pull 0.25, straight 0.21, lofted 0.14, square_cut 0.03, 10.3ms
# 22: 640x640 lofted 0.33, late_cut 0.30, pull 0.20, straight 0.14, square_cut 0.02, 10.3ms
# 23: 640x640 lofted 0.37, late_cut 0.27, pull 0.21, straight 0.14, square_cut 0.01, 10.3ms
# 24: 640x640 lofted 0.74, late_cut 0.13, straight 0.09, pull 0.03, sweep 0.00, 10.3ms
# 25: 640x640 lofted 0.94, late_cut 0.03, straight 0.01, sweep 0.01, pull 0.01, 10.3ms
# 26: 640x640 lofted 0.93, late_cut 0.05, sweep 0.01, straight 0.01, square_cut 0.00, 10.3ms
# 27: 640x640 lofted 0.89, late_cut 0.07, sweep 0.02, straight 0.01, square_cut 0.00, 10.3ms
# 28: 640x640 lofted 0.90, square_cut 0.04, late_cut 0.04, sweep 0.01, cover 0.01, 10.3ms
# 29: 640x640 lofted 0.90, square_cut 0.06, straight 0.02, sweep 0.01, late_cut 0.00, 10.3ms
# 30: 640x640 lofted 0.63, square_cut 0.27, late_cut 0.05, sweep 0.04, straight 0.01, 10.3ms
# 31: 640x640 lofted 0.50, square_cut 0.25, sweep 0.24, straight 0.01, late_cut 0.00, 10.3ms
# Speed: 13.4ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'lofted': 0.25937933661043644, 'straight': 0.17757485434412956, 'pull': 0.14378296118229628, 'late_cut': 0.02307221759110689}
# Video: cover_0061.mp4, Most Probable Class: lofted, Avg Probability: 0.2594
#
# 0: 640x640 lofted 0.32, straight 0.28, square_cut 0.16, cover 0.13, sweep 0.06, 10.3ms
# 1: 640x640 lofted 0.37, square_cut 0.18, straight 0.18, flick 0.12, sweep 0.08, 10.3ms
# 2: 640x640 lofted 0.34, straight 0.23, square_cut 0.20, flick 0.12, sweep 0.07, 10.3ms
# 3: 640x640 lofted 0.63, square_cut 0.15, straight 0.10, flick 0.06, sweep 0.04, 10.3ms
# 4: 640x640 lofted 0.47, straight 0.21, square_cut 0.19, flick 0.07, sweep 0.05, 10.3ms
# 5: 640x640 square_cut 0.38, lofted 0.34, straight 0.17, flick 0.06, cover 0.03, 10.3ms
# 6: 640x640 square_cut 0.65, lofted 0.20, straight 0.06, flick 0.04, cover 0.03, 10.3ms
# 7: 640x640 square_cut 0.62, lofted 0.19, straight 0.11, flick 0.05, cover 0.03, 10.3ms
# 8: 640x640 square_cut 0.63, straight 0.12, lofted 0.12, flick 0.07, cover 0.03, 10.3ms
# 9: 640x640 lofted 0.47, square_cut 0.30, flick 0.10, straight 0.09, cover 0.02, 10.3ms
# 10: 640x640 lofted 0.28, flick 0.22, straight 0.22, square_cut 0.18, cover 0.05, 10.3ms
# 11: 640x640 lofted 0.29, flick 0.24, square_cut 0.23, straight 0.09, sweep 0.08, 10.3ms
# 12: 640x640 lofted 0.33, flick 0.27, square_cut 0.13, straight 0.13, sweep 0.07, 10.3ms
# 13: 640x640 lofted 0.26, square_cut 0.23, straight 0.17, flick 0.16, cover 0.12, 10.3ms
# 14: 640x640 lofted 0.78, cover 0.08, square_cut 0.06, flick 0.03, straight 0.03, 10.3ms
# 15: 640x640 lofted 0.70, flick 0.13, cover 0.07, square_cut 0.05, straight 0.04, 10.3ms
# 16: 640x640 lofted 0.56, cover 0.16, straight 0.14, flick 0.08, hook 0.03, 10.3ms
# 17: 640x640 lofted 0.56, flick 0.23, cover 0.12, square_cut 0.04, straight 0.03, 10.3ms
# 18: 640x640 lofted 0.49, flick 0.34, cover 0.13, straight 0.03, square_cut 0.00, 10.3ms
# 19: 640x640 lofted 0.51, flick 0.35, cover 0.12, straight 0.02, square_cut 0.00, 10.3ms
# 20: 640x640 lofted 0.69, cover 0.16, flick 0.12, square_cut 0.01, pull 0.01, 10.3ms
# 21: 640x640 lofted 0.95, flick 0.01, cover 0.01, square_cut 0.01, straight 0.01, 10.3ms
# 22: 640x640 lofted 0.88, cover 0.05, flick 0.03, square_cut 0.02, sweep 0.01, 10.3ms
# 23: 640x640 lofted 0.84, square_cut 0.05, cover 0.04, flick 0.03, sweep 0.03, 10.3ms
# 24: 640x640 lofted 0.93, cover 0.05, flick 0.01, square_cut 0.00, straight 0.00, 10.3ms
# 25: 640x640 lofted 0.97, cover 0.02, flick 0.01, straight 0.00, square_cut 0.00, 10.3ms
# 26: 640x640 lofted 0.64, cover 0.24, flick 0.11, straight 0.00, square_cut 0.00, 10.3ms
# 27: 640x640 lofted 0.75, flick 0.14, cover 0.10, straight 0.00, square_cut 0.00, 10.3ms
# 28: 640x640 lofted 0.71, cover 0.20, flick 0.08, straight 0.01, square_cut 0.00, 10.3ms
# 29: 640x640 lofted 0.96, cover 0.02, flick 0.01, square_cut 0.00, straight 0.00, 10.3ms
# 30: 640x640 lofted 0.98, cover 0.01, flick 0.01, square_cut 0.00, straight 0.00, 10.3ms
# 31: 640x640 lofted 0.95, flick 0.02, cover 0.01, straight 0.01, square_cut 0.00, 10.3ms
# Speed: 11.9ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'lofted': 0.5498839821666479, 'square_cut': 0.07128182705491781}
# Video: cover_0160.mp4, Most Probable Class: lofted, Avg Probability: 0.5499
#
# 0: 640x640 lofted 0.95, straight 0.02, cover 0.02, flick 0.01, square_cut 0.01, 10.3ms
# 1: 640x640 lofted 0.97, straight 0.01, cover 0.01, flick 0.00, square_cut 0.00, 10.3ms
# 2: 640x640 lofted 0.96, straight 0.03, cover 0.01, square_cut 0.00, flick 0.00, 10.3ms
# 3: 640x640 lofted 0.91, cover 0.04, straight 0.03, flick 0.01, square_cut 0.01, 10.3ms
# 4: 640x640 lofted 0.78, cover 0.17, straight 0.05, flick 0.00, square_cut 0.00, 10.3ms
# 5: 640x640 lofted 0.82, cover 0.14, straight 0.04, flick 0.00, square_cut 0.00, 10.3ms
# 6: 640x640 lofted 0.81, cover 0.15, straight 0.03, flick 0.01, square_cut 0.00, 10.3ms
# 7: 640x640 lofted 0.92, cover 0.06, straight 0.02, flick 0.00, square_cut 0.00, 10.3ms
# 8: 640x640 lofted 0.94, straight 0.04, cover 0.02, flick 0.00, square_cut 0.00, 10.3ms
# 9: 640x640 lofted 0.93, straight 0.06, cover 0.01, flick 0.00, hook 0.00, 10.3ms
# 10: 640x640 lofted 0.97, cover 0.02, straight 0.01, flick 0.00, sweep 0.00, 10.3ms
# 11: 640x640 lofted 0.97, straight 0.02, cover 0.01, flick 0.00, square_cut 0.00, 10.3ms
# 12: 640x640 lofted 0.96, cover 0.02, straight 0.02, flick 0.01, square_cut 0.00, 10.3ms
# 13: 640x640 lofted 0.89, cover 0.08, straight 0.02, flick 0.01, square_cut 0.00, 10.3ms
# 14: 640x640 lofted 0.59, cover 0.37, flick 0.02, straight 0.01, square_cut 0.01, 10.3ms
# 15: 640x640 lofted 0.89, cover 0.08, flick 0.02, straight 0.01, sweep 0.00, 10.3ms
# 16: 640x640 lofted 0.50, cover 0.48, flick 0.01, straight 0.00, square_cut 0.00, 10.3ms
# 17: 640x640 cover 0.44, lofted 0.43, straight 0.09, flick 0.03, square_cut 0.01, 10.3ms
# 18: 640x640 lofted 0.63, cover 0.32, straight 0.04, flick 0.01, sweep 0.00, 10.3ms
# 19: 640x640 lofted 0.61, cover 0.37, straight 0.02, flick 0.00, sweep 0.00, 10.3ms
# 20: 640x640 lofted 0.59, cover 0.37, straight 0.03, sweep 0.01, flick 0.01, 10.3ms
# 21: 640x640 cover 0.65, lofted 0.32, straight 0.02, flick 0.01, sweep 0.00, 10.3ms
# 22: 640x640 cover 0.74, lofted 0.18, straight 0.07, flick 0.01, sweep 0.00, 10.3ms
# 23: 640x640 cover 0.46, lofted 0.41, straight 0.10, flick 0.02, sweep 0.01, 10.3ms
# 24: 640x640 cover 0.50, lofted 0.38, straight 0.08, flick 0.03, sweep 0.00, 10.3ms
# 25: 640x640 cover 0.66, lofted 0.17, straight 0.13, flick 0.03, sweep 0.01, 10.3ms
# 26: 640x640 cover 0.35, straight 0.31, lofted 0.18, sweep 0.09, flick 0.06, 10.3ms
# 27: 640x640 flick 0.52, straight 0.20, cover 0.20, lofted 0.03, sweep 0.03, 10.3ms
# 28: 640x640 cover 0.46, flick 0.41, straight 0.09, lofted 0.02, sweep 0.02, 10.3ms
# 29: 640x640 cover 0.67, flick 0.24, straight 0.07, lofted 0.02, square_cut 0.00, 10.3ms
# 30: 640x640 cover 0.70, flick 0.21, straight 0.03, sweep 0.03, lofted 0.01, 10.3ms
# 31: 640x640 cover 0.79, flick 0.13, straight 0.04, sweep 0.02, lofted 0.01, 10.3ms
# Speed: 13.3ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'lofted': 0.5173897333443165, 'cover': 0.20038850605487823, 'flick': 0.016292838379740715}
# Video: cover_0014.mp4, Most Probable Class: lofted, Avg Probability: 0.5174
#
# 0: 640x640 pull 0.69, hook 0.21, square_cut 0.07, flick 0.02, cover 0.01, 10.3ms
# 1: 640x640 pull 0.60, hook 0.31, square_cut 0.04, flick 0.02, cover 0.02, 10.3ms
# 2: 640x640 pull 0.58, hook 0.33, square_cut 0.04, flick 0.02, cover 0.02, 10.3ms
# 3: 640x640 pull 0.75, hook 0.10, flick 0.06, square_cut 0.03, cover 0.03, 10.3ms
# 4: 640x640 pull 0.50, hook 0.25, square_cut 0.12, flick 0.06, cover 0.02, 10.3ms
# 5: 640x640 pull 0.54, square_cut 0.25, hook 0.14, flick 0.04, cover 0.02, 10.3ms
# 6: 640x640 pull 0.41, hook 0.28, square_cut 0.26, flick 0.03, cover 0.01, 10.3ms
# 7: 640x640 pull 0.69, hook 0.17, square_cut 0.07, flick 0.03, cover 0.02, 10.3ms
# 8: 640x640 pull 0.59, cover 0.15, hook 0.12, square_cut 0.08, flick 0.05, 10.3ms
# 9: 640x640 pull 0.31, cover 0.27, square_cut 0.17, hook 0.16, flick 0.07, 10.3ms
# 10: 640x640 pull 0.34, cover 0.29, square_cut 0.21, flick 0.06, hook 0.05, 10.3ms
# 11: 640x640 pull 0.57, cover 0.16, hook 0.11, square_cut 0.08, flick 0.07, 10.3ms
# 12: 640x640 pull 0.65, cover 0.16, square_cut 0.11, flick 0.06, hook 0.03, 10.3ms
# 13: 640x640 pull 0.63, flick 0.16, square_cut 0.13, cover 0.05, hook 0.03, 10.3ms
# 14: 640x640 pull 0.68, flick 0.14, square_cut 0.11, cover 0.05, lofted 0.01, 10.3ms
# 15: 640x640 pull 0.83, square_cut 0.08, flick 0.04, hook 0.02, cover 0.02, 10.3ms
# 16: 640x640 pull 0.79, square_cut 0.13, flick 0.03, hook 0.03, cover 0.01, 10.3ms
# 17: 640x640 pull 0.27, square_cut 0.21, hook 0.19, sweep 0.17, flick 0.09, 10.3ms
# 18: 640x640 pull 0.51, square_cut 0.34, flick 0.09, hook 0.06, lofted 0.01, 10.3ms
# 19: 640x640 pull 0.35, square_cut 0.30, flick 0.28, hook 0.05, lofted 0.01, 10.3ms
# 20: 640x640 pull 0.81, square_cut 0.09, flick 0.07, hook 0.03, lofted 0.00, 10.3ms
# 21: 640x640 pull 0.61, square_cut 0.25, flick 0.10, hook 0.03, lofted 0.01, 10.3ms
# 22: 640x640 pull 0.84, flick 0.10, square_cut 0.03, lofted 0.02, cover 0.01, 10.3ms
# 23: 640x640 pull 0.69, square_cut 0.15, flick 0.12, lofted 0.03, cover 0.01, 10.3ms
# 24: 640x640 pull 0.42, square_cut 0.40, flick 0.08, cover 0.05, lofted 0.04, 10.3ms
# 25: 640x640 square_cut 0.61, flick 0.21, pull 0.14, cover 0.03, lofted 0.01, 10.3ms
# 26: 640x640 square_cut 0.47, flick 0.32, pull 0.10, cover 0.07, lofted 0.03, 10.3ms
# 27: 640x640 square_cut 0.39, pull 0.31, flick 0.21, cover 0.06, lofted 0.02, 10.3ms
# 28: 640x640 flick 0.44, square_cut 0.23, pull 0.16, lofted 0.08, cover 0.08, 10.3ms
# 29: 640x640 flick 0.38, pull 0.29, cover 0.15, lofted 0.13, square_cut 0.05, 10.3ms
# 30: 640x640 lofted 0.48, cover 0.24, pull 0.14, square_cut 0.10, flick 0.04, 10.3ms
# 31: 640x640 lofted 0.47, cover 0.27, flick 0.11, square_cut 0.07, pull 0.07, 10.3ms
# Speed: 13.2ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'pull': 0.4577254354953766, 'square_cut': 0.04606546740978956, 'flick': 0.02582536730915308, 'lofted': 0.029828867875039577}
# Video: cover_0145.mp4, Most Probable Class: pull, Avg Probability: 0.4577
#
# 0: 640x640 square_cut 0.67, cover 0.13, hook 0.09, pull 0.04, flick 0.03, 10.7ms
# 1: 640x640 square_cut 0.49, cover 0.30, hook 0.08, flick 0.05, pull 0.05, 10.7ms
# 2: 640x640 square_cut 0.51, cover 0.22, pull 0.13, flick 0.07, hook 0.03, 10.7ms
# 3: 640x640 square_cut 0.47, cover 0.16, flick 0.14, pull 0.12, straight 0.05, 10.7ms
# 4: 640x640 square_cut 0.63, pull 0.15, flick 0.12, cover 0.06, straight 0.02, 10.7ms
# 5: 640x640 flick 0.86, lofted 0.08, straight 0.02, cover 0.02, pull 0.02, 10.7ms
# 6: 640x640 flick 0.84, lofted 0.08, straight 0.03, sweep 0.02, cover 0.01, 10.7ms
# 7: 640x640 flick 0.62, straight 0.13, pull 0.13, lofted 0.07, square_cut 0.03, 10.7ms
# 8: 640x640 flick 0.49, straight 0.20, lofted 0.13, cover 0.11, square_cut 0.03, 10.7ms
# 9: 640x640 straight 0.41, flick 0.23, lofted 0.13, square_cut 0.09, pull 0.07, 10.7ms
# 10: 640x640 lofted 0.30, straight 0.29, flick 0.16, square_cut 0.12, pull 0.06, 10.7ms
# 11: 640x640 square_cut 0.56, lofted 0.22, straight 0.10, cover 0.04, sweep 0.03, 10.7ms
# 12: 640x640 square_cut 0.62, straight 0.13, lofted 0.10, cover 0.10, flick 0.02, 10.7ms
# 13: 640x640 cover 0.38, lofted 0.25, square_cut 0.15, flick 0.12, straight 0.08, 10.7ms
# 14: 640x640 straight 0.59, square_cut 0.30, cover 0.04, late_cut 0.03, lofted 0.02, 10.7ms
# 15: 640x640 square_cut 0.88, cover 0.09, pull 0.02, straight 0.01, flick 0.00, 10.7ms
# 16: 640x640 square_cut 0.73, cover 0.16, sweep 0.05, pull 0.04, straight 0.01, 10.7ms
# 17: 640x640 square_cut 0.38, cover 0.35, straight 0.11, sweep 0.06, pull 0.04, 10.7ms
# 18: 640x640 pull 0.67, square_cut 0.13, straight 0.10, cover 0.05, flick 0.02, 10.7ms
# 19: 640x640 straight 0.59, cover 0.27, flick 0.06, pull 0.03, square_cut 0.02, 10.7ms
# 20: 640x640 cover 0.48, flick 0.18, square_cut 0.09, lofted 0.09, sweep 0.07, 10.7ms
# 21: 640x640 cover 0.70, square_cut 0.16, flick 0.05, lofted 0.04, straight 0.02, 10.7ms
# 22: 640x640 cover 0.80, square_cut 0.09, lofted 0.05, flick 0.02, late_cut 0.02, 10.7ms
# 23: 640x640 cover 0.83, lofted 0.05, square_cut 0.04, flick 0.04, straight 0.02, 10.7ms
# 24: 640x640 cover 0.45, square_cut 0.34, lofted 0.10, flick 0.05, late_cut 0.03, 10.7ms
# 25: 640x640 cover 0.98, square_cut 0.01, late_cut 0.00, flick 0.00, lofted 0.00, 10.7ms
# 26: 640x640 cover 0.98, square_cut 0.01, lofted 0.01, flick 0.00, straight 0.00, 10.7ms
# 27: 640x640 cover 0.98, lofted 0.01, flick 0.00, square_cut 0.00, straight 0.00, 10.7ms
# 28: 640x640 cover 0.93, lofted 0.03, straight 0.02, flick 0.01, square_cut 0.01, 10.7ms
# 29: 640x640 cover 0.32, lofted 0.23, flick 0.22, sweep 0.10, square_cut 0.08, 10.7ms
# 30: 640x640 cover 0.69, straight 0.17, lofted 0.07, square_cut 0.03, flick 0.02, 10.7ms
# 31: 640x640 cover 0.72, lofted 0.10, flick 0.07, straight 0.04, late_cut 0.03, 10.7ms
# Speed: 14.9ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'square_cut': 0.18588257767260075, 'flick': 0.08778283093124628, 'straight': 0.049824219197034836, 'lofted': 0.00926805380731821, 'cover': 0.28892518393695354, 'pull': 0.020848406478762627}
# Video: cover_0077.mp4, Most Probable Class: cover, Avg Probability: 0.2889
#
# 0: 640x640 pull 0.63, square_cut 0.15, lofted 0.11, hook 0.09, flick 0.01, 10.3ms
# 1: 640x640 pull 0.62, square_cut 0.15, lofted 0.11, hook 0.10, flick 0.01, 10.3ms
# 2: 640x640 pull 0.64, square_cut 0.15, lofted 0.15, hook 0.04, flick 0.01, 10.3ms
# 3: 640x640 pull 0.59, lofted 0.17, square_cut 0.13, hook 0.08, flick 0.02, 10.3ms
# 4: 640x640 pull 0.53, square_cut 0.20, hook 0.16, lofted 0.09, flick 0.02, 10.3ms
# 5: 640x640 pull 0.53, square_cut 0.19, hook 0.18, lofted 0.06, flick 0.03, 10.3ms
# 6: 640x640 pull 0.41, square_cut 0.27, lofted 0.17, hook 0.06, flick 0.05, 10.3ms
# 7: 640x640 pull 0.56, square_cut 0.21, hook 0.13, lofted 0.06, cover 0.02, 10.3ms
# 8: 640x640 pull 0.68, hook 0.24, square_cut 0.04, lofted 0.02, flick 0.01, 10.3ms
# 9: 640x640 pull 0.61, square_cut 0.22, hook 0.07, lofted 0.07, cover 0.02, 10.3ms
# 10: 640x640 pull 0.56, square_cut 0.24, lofted 0.09, hook 0.06, flick 0.02, 10.3ms
# 11: 640x640 square_cut 0.35, pull 0.27, lofted 0.19, hook 0.13, cover 0.04, 10.3ms
# 12: 640x640 square_cut 0.31, lofted 0.28, cover 0.20, pull 0.16, flick 0.02, 10.3ms
# 13: 640x640 pull 0.43, lofted 0.41, square_cut 0.08, cover 0.04, late_cut 0.02, 10.3ms
# 14: 640x640 pull 0.67, lofted 0.20, square_cut 0.06, cover 0.04, straight 0.01, 10.3ms
# 15: 640x640 lofted 0.49, pull 0.28, cover 0.14, square_cut 0.05, sweep 0.03, 10.3ms
# 16: 640x640 pull 0.50, lofted 0.36, sweep 0.08, square_cut 0.03, straight 0.01, 10.3ms
# 17: 640x640 pull 0.74, lofted 0.25, straight 0.01, sweep 0.00, square_cut 0.00, 10.3ms
# 18: 640x640 lofted 0.63, pull 0.27, straight 0.03, square_cut 0.03, sweep 0.03, 10.3ms
# 19: 640x640 lofted 0.52, pull 0.33, straight 0.12, sweep 0.02, late_cut 0.00, 10.3ms
# 20: 640x640 lofted 0.63, straight 0.18, pull 0.17, sweep 0.01, square_cut 0.01, 10.3ms
# 21: 640x640 straight 0.66, lofted 0.30, pull 0.04, cover 0.00, sweep 0.00, 10.3ms
# 22: 640x640 straight 0.64, lofted 0.31, pull 0.02, square_cut 0.01, sweep 0.01, 10.3ms
# 23: 640x640 straight 0.49, lofted 0.30, sweep 0.08, pull 0.05, square_cut 0.05, 10.3ms
# 24: 640x640 straight 0.62, lofted 0.18, square_cut 0.09, pull 0.08, cover 0.02, 10.3ms
# 25: 640x640 straight 0.61, lofted 0.19, square_cut 0.08, cover 0.05, pull 0.04, 10.3ms
# 26: 640x640 straight 0.74, lofted 0.09, square_cut 0.06, pull 0.04, late_cut 0.04, 10.3ms
# 27: 640x640 late_cut 0.45, pull 0.34, cover 0.06, flick 0.06, square_cut 0.05, 10.3ms
# 28: 640x640 late_cut 0.72, pull 0.12, cover 0.06, square_cut 0.05, sweep 0.02, 10.3ms
# 29: 640x640 late_cut 0.92, cover 0.02, sweep 0.02, pull 0.02, flick 0.01, 10.3ms
# 30: 640x640 late_cut 0.74, sweep 0.09, square_cut 0.08, flick 0.04, cover 0.04, 10.3ms
# 31: 640x640 late_cut 0.80, square_cut 0.08, sweep 0.06, flick 0.04, pull 0.01, 10.3ms
# Speed: 13.1ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'pull': 0.2710816105827689, 'square_cut': 0.020521455444395542, 'lofted': 0.07080570701509714, 'straight': 0.11789555288851261, 'late_cut': 0.11339458636939526}
# Video: cover_0082.mp4, Most Probable Class: pull, Avg Probability: 0.2711
#
# 0: 640x640 square_cut 0.42, lofted 0.20, flick 0.17, hook 0.16, pull 0.04, 10.3ms
# 1: 640x640 square_cut 0.78, hook 0.08, lofted 0.07, flick 0.06, pull 0.01, 10.3ms
# 2: 640x640 square_cut 0.81, flick 0.08, hook 0.06, lofted 0.04, pull 0.01, 10.3ms
# 3: 640x640 square_cut 0.78, flick 0.08, hook 0.07, lofted 0.05, pull 0.01, 10.3ms
# 4: 640x640 square_cut 0.78, flick 0.10, lofted 0.06, hook 0.05, pull 0.01, 10.3ms
# 5: 640x640 square_cut 0.63, flick 0.23, lofted 0.08, hook 0.04, pull 0.01, 10.3ms
# 6: 640x640 square_cut 0.51, flick 0.31, hook 0.10, lofted 0.07, pull 0.01, 10.3ms
# 7: 640x640 square_cut 0.71, flick 0.15, hook 0.08, lofted 0.05, pull 0.01, 10.3ms
# 8: 640x640 square_cut 0.72, hook 0.13, flick 0.11, lofted 0.03, pull 0.01, 10.3ms
# 9: 640x640 square_cut 0.77, flick 0.11, hook 0.07, lofted 0.03, pull 0.01, 10.3ms
# 10: 640x640 square_cut 0.77, hook 0.11, flick 0.08, lofted 0.02, pull 0.01, 10.3ms
# 11: 640x640 flick 0.40, square_cut 0.27, lofted 0.22, hook 0.08, pull 0.02, 10.3ms
# 12: 640x640 square_cut 0.36, flick 0.33, lofted 0.20, hook 0.08, pull 0.02, 10.3ms
# 13: 640x640 square_cut 0.46, flick 0.35, hook 0.12, lofted 0.06, pull 0.00, 10.3ms
# 14: 640x640 square_cut 0.67, hook 0.14, flick 0.14, lofted 0.05, pull 0.01, 10.3ms
# 15: 640x640 square_cut 0.79, hook 0.10, flick 0.08, lofted 0.02, pull 0.00, 10.3ms
# 16: 640x640 square_cut 0.68, lofted 0.15, flick 0.11, hook 0.06, pull 0.01, 10.3ms
# 17: 640x640 square_cut 0.96, flick 0.02, lofted 0.01, sweep 0.00, hook 0.00, 10.3ms
# 18: 640x640 square_cut 0.94, lofted 0.04, hook 0.01, flick 0.01, pull 0.00, 10.3ms
# 19: 640x640 square_cut 0.97, lofted 0.01, sweep 0.00, flick 0.00, hook 0.00, 10.3ms
# 20: 640x640 square_cut 0.66, lofted 0.25, flick 0.07, sweep 0.01, cover 0.01, 10.3ms
# 21: 640x640 square_cut 0.74, flick 0.16, lofted 0.09, cover 0.01, hook 0.01, 10.3ms
# 22: 640x640 square_cut 0.89, flick 0.06, lofted 0.03, sweep 0.01, straight 0.00, 10.3ms
# 23: 640x640 square_cut 0.98, lofted 0.01, flick 0.01, sweep 0.00, straight 0.00, 10.3ms
# 24: 640x640 square_cut 0.95, lofted 0.02, straight 0.01, flick 0.01, cover 0.00, 10.3ms
# 25: 640x640 square_cut 0.92, straight 0.03, lofted 0.03, flick 0.01, sweep 0.01, 10.3ms
# 26: 640x640 square_cut 0.78, straight 0.08, sweep 0.07, lofted 0.04, cover 0.01, 10.3ms
# 27: 640x640 square_cut 0.70, straight 0.10, lofted 0.07, sweep 0.05, flick 0.04, 10.3ms
# 28: 640x640 square_cut 0.54, straight 0.21, lofted 0.16, cover 0.05, flick 0.03, 10.3ms
# 29: 640x640 square_cut 0.50, lofted 0.21, cover 0.13, straight 0.12, flick 0.04, 10.3ms
# 30: 640x640 square_cut 0.35, lofted 0.33, cover 0.16, flick 0.13, straight 0.02, 10.3ms
# 31: 640x640 square_cut 0.31, flick 0.24, lofted 0.22, cover 0.18, straight 0.03, 10.3ms
# Speed: 9.4ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'square_cut': 0.6823508329689503, 'flick': 0.012631835415959358}
# Video: cover_0111.mp4, Most Probable Class: square_cut, Avg Probability: 0.6824
#
# 0: 640x640 straight 0.66, lofted 0.18, cover 0.13, pull 0.02, hook 0.00, 10.3ms
# 1: 640x640 straight 0.39, lofted 0.29, cover 0.27, pull 0.05, hook 0.00, 10.3ms
# 2: 640x640 straight 0.38, lofted 0.30, cover 0.26, pull 0.06, hook 0.00, 10.3ms
# 3: 640x640 straight 0.53, lofted 0.31, cover 0.11, pull 0.05, hook 0.00, 10.3ms
# 4: 640x640 lofted 0.56, straight 0.23, pull 0.11, cover 0.10, hook 0.00, 10.3ms
# 5: 640x640 lofted 0.40, cover 0.21, straight 0.21, pull 0.17, hook 0.01, 10.3ms
# 6: 640x640 cover 0.48, straight 0.41, pull 0.04, lofted 0.04, hook 0.02, 10.3ms
# 7: 640x640 straight 0.87, cover 0.11, pull 0.01, lofted 0.01, hook 0.00, 10.3ms
# 8: 640x640 straight 0.51, cover 0.36, lofted 0.08, pull 0.04, hook 0.01, 10.3ms
# 9: 640x640 straight 0.51, cover 0.36, lofted 0.08, pull 0.04, hook 0.01, 10.3ms
# 10: 640x640 straight 0.87, cover 0.09, hook 0.02, pull 0.02, lofted 0.00, 10.3ms
# 11: 640x640 straight 0.90, cover 0.08, pull 0.02, hook 0.00, flick 0.00, 10.3ms
# 12: 640x640 straight 0.92, cover 0.07, pull 0.01, lofted 0.00, flick 0.00, 10.3ms
# 13: 640x640 straight 0.61, cover 0.38, pull 0.01, lofted 0.00, flick 0.00, 10.3ms
# 14: 640x640 straight 0.58, cover 0.41, pull 0.01, lofted 0.01, flick 0.00, 10.3ms
# 15: 640x640 cover 0.34, straight 0.32, lofted 0.23, pull 0.10, flick 0.01, 10.3ms
# 16: 640x640 straight 0.42, lofted 0.42, cover 0.11, pull 0.04, flick 0.00, 10.3ms
# 17: 640x640 straight 0.51, lofted 0.37, cover 0.08, pull 0.03, sweep 0.01, 10.3ms
# 18: 640x640 lofted 0.85, straight 0.10, cover 0.03, pull 0.02, sweep 0.01, 10.3ms
# 19: 640x640 lofted 0.74, straight 0.24, cover 0.02, pull 0.00, sweep 0.00, 10.3ms
# 20: 640x640 straight 0.57, lofted 0.37, cover 0.04, pull 0.02, sweep 0.01, 10.3ms
# 21: 640x640 cover 0.68, straight 0.26, lofted 0.06, pull 0.00, late_cut 0.00, 10.3ms
# 22: 640x640 cover 0.63, lofted 0.26, straight 0.11, sweep 0.00, pull 0.00, 10.3ms
# 23: 640x640 cover 0.90, lofted 0.07, straight 0.02, sweep 0.00, pull 0.00, 10.3ms
# 24: 640x640 cover 0.83, straight 0.08, lofted 0.07, flick 0.00, pull 0.00, 10.3ms
# 25: 640x640 cover 0.88, lofted 0.05, flick 0.04, straight 0.03, pull 0.00, 10.3ms
# 26: 640x640 cover 0.77, lofted 0.13, straight 0.07, flick 0.02, sweep 0.01, 10.3ms
# 27: 640x640 cover 0.83, straight 0.10, lofted 0.06, flick 0.01, sweep 0.00, 10.3ms
# 28: 640x640 cover 0.61, straight 0.27, lofted 0.09, flick 0.02, sweep 0.01, 10.3ms
# 29: 640x640 cover 0.62, lofted 0.24, straight 0.07, flick 0.06, sweep 0.02, 10.3ms
# 30: 640x640 cover 0.50, lofted 0.31, straight 0.15, sweep 0.04, flick 0.00, 10.3ms
# 31: 640x640 straight 0.49, pull 0.31, lofted 0.07, cover 0.05, flick 0.04, 10.3ms
# Speed: 12.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# {'straight': 0.3031797716394067, 'lofted': 0.0796007327735424, 'cover': 0.252787665463984}
# Video: cover_0049.mp4, Most Probable Class: straight, Avg Probability: 0.3032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 45
#      41 video_path = os.path.join(class_dir, video_name)
#      43 try:
#      44     # Extract 32 frames from the video
# ---> 45     frames = extract_frames(video_path, num_frames=32)
#      47     # Predict on video frames
#      48     results = model.predict(frames)
#
# Cell In[12], line 26, in extract_frames(video_path, num_frames, img_size)
#      24 frames = []
#      25 for i in range(num_frames):
# ---> 26     cap.set(cv2.CAP_PROP_POS_FRAMES, i * interval)
#      27     ret, frame = cap.read()
#      28     if not ret:
#
# KeyboardInterrupt:

# %%
# Merge predictions with ground truth for comparison
comparison_df = predictions_df

# comparison_df.to_csv("comperision_df.csv",index=False)
# Display the comparison DataFrame
comparison_df

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Assume comparison_df is already created

# Calculate accuracy
accuracy = accuracy_score(comparison_df['true_class'], comparison_df['predicted_class'])
print(f"Accuracy: {accuracy:.2f}")

# Generate classification report
class_report = classification_report(comparison_df['true_class'], comparison_df['predicted_class'], target_names=os.listdir(test_base_dir))
print("Classification Report:\n", class_report)

# Generate confusion matrix
cm = confusion_matrix(comparison_df['true_class'], comparison_df['predicted_class'], labels=os.listdir(test_base_dir))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=os.listdir(test_base_dir), yticklabels=os.listdir(test_base_dir))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Calculate classification errors
comparison_df['error'] = comparison_df['true_class'] != comparison_df['predicted_class']
error_count = comparison_df['error'].sum()
total_count = len(comparison_df)
error_rate = error_count / total_count

print(f"Total classification errors: {error_count}")
print(f"Error rate: {error_rate:.2f}")

# %%
import os
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Assume comparison_df is already created

# Calculate accuracy
accuracy = accuracy_score(comparison_df['true_class'], comparison_df['predicted_class'])
accuracy_percentage = accuracy * 100
accuracy_formatted = f"{accuracy:.6f}"
accuracy_percentage_formatted = f"{accuracy_percentage:.4f}%"
print(f"Accuracy: {accuracy_formatted} ({accuracy_percentage_formatted})")

# Generate classification report
class_report = classification_report(comparison_df['true_class'], comparison_df['predicted_class'], target_names=os.listdir(test_base_dir), digits=4)
print("Classification Report:\n", class_report)

# Generate confusion matrix
cm = confusion_matrix(comparison_df['true_class'], comparison_df['predicted_class'], labels=os.listdir(test_base_dir))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=os.listdir(test_base_dir), yticklabels=os.listdir(test_base_dir))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')  # Save as PNG
plt.show()
plt.close()  # Close the plot to free memory

# Calculate classification errors
comparison_df['error'] = comparison_df['true_class'] != comparison_df['predicted_class']
error_count = comparison_df['error'].sum()
total_count = len(comparison_df)
error_rate = error_count / total_count
error_rate_percentage = error_rate * 100
error_rate_formatted = f"{error_rate:.4f}"
error_rate_percentage_formatted = f"{error_rate_percentage:.2f}%"

print(f"Total classification errors: {error_count}")
print(f"Error rate: {error_rate_formatted} ({error_rate_percentage_formatted})")

# Export the results
# 1. Save accuracy to a text file
with open('accuracy.txt', 'w') as f:
    f.write(f"Accuracy: {accuracy_formatted} ({accuracy_percentage_formatted})\n")

# 2. Save classification report to a text file
with open('classification_report.txt', 'w') as f:
    f.write("Classification Report:\n")
    f.write(class_report)

# 3. Save the comparison DataFrame including errors to a CSV file
comparison_df.to_csv('classification_errors.csv', index=False)

# 4. Save error summary to a text file
with open('error_summary.txt', 'w') as f:
    f.write(f"Total classification errors: {error_count}\n")
    f.write(f"Error rate: {error_rate_formatted} ({error_rate_percentage_formatted})\n")
